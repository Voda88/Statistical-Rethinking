# %% [markdown]
# # Chapter 5

# %%
import pandas as pd
import numpy as np
import arviz as az
import matplotlib.pyplot as plt
import pymc3 as pm
import seaborn as sns
import ptitprince as pt
import scipy.stats as stats
# Out:
# C:\Users\Mikko\AppData\Local\Continuum\anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# C:\Users\Mikko\AppData\Local\Continuum\anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
az.style.use('arviz-darkgrid')

# %% [markdown]
# ### Load the data "WaffleDivorce"

# %%
df = pd.read_csv('../resources/Rethinking/Data/WaffleDivorce.csv', sep = ';')

# %%
df.head(3)
# Out:
#   Location Loc  Population  MedianAgeMarriage  Marriage  Marriage SE  Divorce  \
# 0  Alabama  AL        4.78               25.3      20.2         1.27     12.7
# 1   Alaska  AK        0.71               25.2      26.0         2.93     12.5
# 2  Arizona  AZ        6.33               25.8      20.3         0.98     10.8
#
#    Divorce SE  WaffleHouses  South  Slaves1860  Population1860  PropSlaves1860
# 0        0.79           128      1      435080          964201            0.45
# 1        2.05             0      0           0               0            0.00
# 2        0.74            18      0           0               0            0.00

# %%
df.tail(3)
# Out:
#          Location Loc  Population  MedianAgeMarriage  Marriage  Marriage SE  \
# 47  West Virginia  WV        1.85               25.0      22.2         1.69
# 48      Wisconsin  WI        5.69               26.3      17.2         0.79
# 49        Wyoming  WY        0.56               24.2      30.7         3.92
#
#     Divorce  Divorce SE  WaffleHouses  South  Slaves1860  Population1860  \
# 47     10.9        1.34             4      1       18371          376688
# 48      8.3        0.57             0      0           0          775881
# 49     10.3        1.90             0      0           0               0
#
#     PropSlaves1860
# 47           0.049
# 48           0.000
# 49           0.000

# %%
df['MedianAgeMarriage_s'] = (df['MedianAgeMarriage']-df['MedianAgeMarriage'].mean())/df['MedianAgeMarriage'].std()

# %%
df['Divorce_s'] = (df['Divorce'] - df['Divorce'].mean())/df['Divorce'].std()

# %%
df['Marriage_s'] = (df['Marriage'] - df['Marriage'].mean())/df['Marriage'].std()

# %%
df.head(2)
# Out:
#   Location Loc  Population  MedianAgeMarriage  Marriage  Marriage SE  Divorce  \
# 0  Alabama  AL        4.78               25.3      20.2         1.27     12.7
# 1   Alaska  AK        0.71               25.2      26.0         2.93     12.5
#
#    Divorce SE  WaffleHouses  South  Slaves1860  Population1860  \
# 0        0.79           128      1      435080          964201
# 1        2.05             0      0           0               0
#
#    PropSlaves1860  MedianAgeMarriage_s  Divorce_s  Marriage_s
# 0            0.45            -0.606290   1.654205    0.022644
# 1            0.00            -0.686699   1.544364    1.549802

# %% [markdown]
# ### Linear regression model with median age of marriage as predictor for divorce:

# %% [markdown]
# $$ D_i \sim N(\mu_i, \sigma) $$
# $$ \mu_i = \alpha + \beta_A A_i $$
# $$ \alpha \sim N(0, 0.2) $$
# $$ \beta_A \sim N(0, 0.5) $$
# $$ \sigma \sim Exp(1) $$

# %% [markdown]
# ## Choosing priors

# %%
df['MedianAgeMarriage'].std()
# Out:
# 1.243630301388082

# %% [markdown]
# Slope of 1 would mean that 1 year difference in median age of marriage would cause a 1 standard deviation difference in divorce rates: implausible.

# %% [markdown]
# ### Sample with MCMC using pymc3:

# %%
with pm.Model() as model_51:
    alpha = pm.Normal('alpha', 0, 0.2)
    beta = pm.Normal('beta', 0, 0.5)
    sigma = pm.Exponential('sigma', 1)
    mu = pm.Deterministic('mu', alpha + beta * df['MedianAgeMarriage_s'])
    D_i = pm.Normal('Divorce', mu, sigma, observed = df['Divorce_s'])
    trace_51 = pm.sample(1000, tune = 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta, alpha]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:04<00:00, 1811.97draws/s]

# %% [markdown]
# ### Visualize results by taking a random sample of fits

# %%
trace_df = pm.trace_to_dataframe(trace_51)

# %%
len(trace_51['alpha'])
# Out:
# 4000

# %%
row = np.random.choice(4000, 500)

# %%
x = np.linspace(-3,3,100)

# %%
y =  trace_df['alpha'][row].values + np.outer(x,trace_df['beta'][row].values)

# %%
az.plot_hpd(df['MedianAgeMarriage_s'], trace_51['mu'])
plt.scatter(df['MedianAgeMarriage_s'], df['Divorce_s'])
plt.plot(df['MedianAgeMarriage_s'], trace_51['alpha'].mean() + trace_51['beta'].mean()* df['MedianAgeMarriage_s'], c ='C1')

# %% [markdown]
# ### Drawing Directed Acyclic Diagrams (DAG)

# %%
import networkx as nx

# %%
G = nx.DiGraph()

# %%
G.add_node('A')
G.add_node('M')
G.add_node('D')

G.add_edge('A','M')
G.add_edge('A','D')
G.add_edge('M','D')

pos=nx.spring_layout(G)
nx.draw(G, pos , with_labels = True)

# %% [markdown]
# ### New model with multiple regression

# %% [markdown]
# $$ D_i \sim N(\mu_i, \sigma) $$
# $$ \mu_i = \alpha  + \beta_A A_i + \beta_M  M_i$$
# $$ \alpha \sim N(0, 0.02) $$
# $$ \beta_M \sim N(0,0.5) $$
# $$ \beta_A \sim N(0,0.5) $$
# $$ \sigma \sim Exp(1) $$

# %% [markdown]
# ### Estimating the posterior

# %%
with pm.Model() as model_52:
    sigma = pm.Exponential('sigma',1)
    alpha = pm.Normal('alpha', 0,0.02)
    beta_a = pm.Normal('beta_a', 0,0.5)
    beta_m = pm.Normal('beta_m', 0, 0.5)
    mu = pm.Deterministic('mu', alpha+beta_a*df['MedianAgeMarriage_s'] +beta_m*df['Marriage_s'])
    divorces = pm.Normal('divorce', mu, sigma, observed = df['Divorce_s'])
    trace_52 = pm.sample(1000, tune = 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta_m, beta_a, alpha, sigma]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:05<00:00, 1509.29draws/s]

# %%
var_names = '~mu'

# %%
pm.forestplot(trace_52, varnames=['beta_a', 'beta_m'])
# Out:
# GridSpec(1, 2, width_ratios=[3, 1])

# %% [markdown]
# ### Effect of marriage rate alone on divorce

# %% [markdown]
# $$ M_i \sim N(\mu_i, \sigma) $$
# $$ \mu_i = \alpha + \beta * A_i $$
# $$ \alpha \sim N(0, 0.02) $$
# $$ \beta \sim N(0,0.5) $$
# $$ \sigma \sim Exp(1) $$

# %%
with pm.Model() as model_53:
    sigma = pm.Exponential('sigma', 1)
    alpha = pm.Normal('alpha', 0,0.02)
    beta = pm.Normal('beta', 0, 0.5)
    mu = pm.Deterministic('mu', alpha + beta * df['MedianAgeMarriage_s'])
    marriage = pm.Normal('marriage', mu, sigma, observed = df['Marriage_s'])
    trace_53 = pm.sample(1000, tune = 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, alpha, sigma]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:04<00:00, 1613.25draws/s]

# %%
mu_pred_53 = trace_53['mu'].mean(0)
mu_residual_53 = df['Marriage_s'] - mu_pred_53

# %%
idx_53 = np.argsort(df['MedianAgeMarriage_s'])

# %%
df.plot('MedianAgeMarriage_s', 'Marriage_s', kind='scatter', xlim=(-3,3), ylim=(-3,3))
plt.plot(df['MedianAgeMarriage_s'][idx_53], trace_53['alpha'].mean() + trace_53['beta'].mean() * df['MedianAgeMarriage_s'][idx_53], 'k');
plt.vlines(df['MedianAgeMarriage_s'], mu_pred_53, mu_pred_53 + mu_residual_53, colors ='grey')

# %%
with pm.Model() as model_54:
    sigma = pm.Exponential('sigma', 1)
    alpha = pm.Normal('alpha', 0,0.02)
    beta = pm.Normal('beta', 0, 0.5)
    mu = pm.Deterministic('mu', alpha + beta * df['Marriage_s'])
    marriage = pm.Normal('MedianAgeMarriage', mu, sigma, observed = df['MedianAgeMarriage_s'])
    trace_54 = pm.sample(1000, tune = 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, alpha, sigma]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:04<00:00, 1769.10draws/s]

# %%
mu_pred_54 = trace_54['mu'].mean(0)
mu_residual_54 = df['MedianAgeMarriage_s'] - mu_pred_54

# %%
idx_54 = np.argsort(df['Marriage_s'])

# %%
plt.scatter(df['Marriage_s'], df['MedianAgeMarriage_s'])
plt.plot(df['Marriage_s'][idx_54], mu_pred_54[idx_54], 'k')
plt.vlines(df['Marriage_s'], mu_pred_54, mu_pred_54+ mu_residual_54, color = 'grey')

# %% [markdown]
# ### Counterfactual plots

# %%
plt.scatter(df['Marriage_s'], df['Divorce_s'])
plt.plot(r_avg, trace_52['alpha'].mean() +  trace_52['beta_m'].mean(0) * r_avg)
r_avg = np.linspace(-3,3,100)
mu_pred = trace_52['alpha'] + trace_52['beta_m']*r_avg[:,None]
divorce_samples = stats.norm.rvs(mu_pred, trace_52['sigma'])
az.plot_hpd(r_avg, divorce_samples.T)
az.plot_hpd(r_avg, mu_pred.T)

# %%
r_avg = np.linspace(-3,3,100)
mu_pred = trace_52['alpha'] + trace_52['beta_a'] * r_avg[:,None]
divorce_samples = stats.norm.rvs(mu_pred, trace_52['sigma'])

plt.scatter(df['MedianAgeMarriage_s'], df['Divorce_s'])
plt.plot(r_avg, trace_52['alpha'].mean() + trace_52['beta_a'].mean(0) * r_avg[:,None])
az.plot_hpd(r_avg, divorce_samples.T)
az.plot_hpd(r_avg, mu_pred.T)

# %% [markdown]
# ### Posterior prediction plots

# %%
mu_pred = trace_52['mu']
divorce_pred = pm.sample_posterior_predictive(trace_52, samples = 1000, model = model_52)['divorce']
divorce_hpd = pm.hpd(divorce_pred)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 2992.77it/s]

# %%
mu_hpd = az.hpd(mu_pred, credible_interval = 0.95)
plt.errorbar(df['Divorce_s'], divorce_pred.mean(0), yerr = np.abs(divorce_pred.mean(0) - mu_hpd.T), fmt = 'C0o')
plt.xlabel('Observed divorce', fontsize=14)
plt.ylabel('Predicted divorce', fontsize=14)

min_x, max_x = df['Divorce_s'].min(), df['Divorce_s'].max()
plt.plot([min_x, max_x], [min_x, max_x], 'k--');

# %%
plt.figure(figsize = (10,12))
residuals = df['Divorce_s'] - mu_pred.mean(0)
idx = np.argsort(residuals)
y_label = df.Loc[idx]
y_points = np.linspace(0,1,50)

plt.errorbar(residuals[idx], y_points, xerr = np.abs(divorce_pred.mean(0), divorce_hpd.T), fmt = 'C0o', lw = 3, alpha = 0.5)

plt.errorbar(residuals[idx], y_points, 
             xerr=np.abs(divorce_pred.mean(0)-mu_hpd.T),
             fmt='C0o',lw=3)

plt.yticks(y_points, y_label);
plt.vlines(0, 0, 1, 'grey');

# %%
N = 100
x_real = stats.norm.rvs(loc = 0,  scale = 1, size = N)
x_spur = stats.norm.rvs(loc = x_real, scale = 1, size = N)
y = stats.norm.rvs(loc = x_real, scale = 1, size = N)
df_ = pd.DataFrame([x_real, x_spur, y]).T

# %%
df_.head()
# Out:
#           0         1         2
# 0  0.294109 -0.665166  0.551818
# 1 -0.716875 -1.544042 -1.048662
# 2 -1.983559 -0.861809 -2.057243
# 3  0.409754  2.703617 -0.000239
# 4 -0.073757 -1.094204  0.552176

# %%
import seaborn as sns

# %%
sns.pairplot(df_)

# %% [markdown]
# ## Masked relationships

# %%
df = pd.read_csv('../resources/Rethinking/Data/milk.csv', sep =';')

# %%
df
# Out:
#                clade                   species  kcal.per.g  perc.fat  \
# 0      Strepsirrhine            Eulemur fulvus        0.49     16.60
# 1      Strepsirrhine                  E macaco        0.51     19.27
# 2      Strepsirrhine                  E mongoz        0.46     14.11
# 3      Strepsirrhine             E rubriventer        0.48     14.91
# 4      Strepsirrhine               Lemur catta        0.60     27.28
# 5   New World Monkey        Alouatta seniculus        0.47     21.22
# 6   New World Monkey                A palliata        0.56     29.66
# 7   New World Monkey              Cebus apella        0.89     53.41
# 8   New World Monkey       Saimiri boliviensis        0.91     46.08
# 9   New World Monkey                S sciureus        0.92     50.58
# 10  New World Monkey          Cebuella pygmaea        0.80     41.35
# 11  New World Monkey         Callimico goeldii        0.46      3.93
# 12  New World Monkey        Callithrix jacchus        0.71     38.38
# ...

# %%
df[df['neocortex.perc'].isna()]
# Out:
#                clade                   species  kcal.per.g  perc.fat  \
# 1      Strepsirrhine                  E macaco        0.51     19.27
# 2      Strepsirrhine                  E mongoz        0.46     14.11
# 3      Strepsirrhine             E rubriventer        0.48     14.91
# 4      Strepsirrhine               Lemur catta        0.60     27.28
# 8   New World Monkey       Saimiri boliviensis        0.91     46.08
# 13  New World Monkey    Leontopithecus rosalia        0.71     36.90
# 14  Old World Monkey   Chlorocebus pygerythrus        0.73     39.17
# 16  Old World Monkey                 M fuscata        0.72     53.05
# 18  Old World Monkey                  M sinica        0.79     48.90
# 20               Ape         Nomascus concolor        0.48     15.96
# 22               Ape  Symphalangus syndactylus        0.51     26.42
# 25               Ape        G gorilla beringei        0.53     30.59
#
#     perc.protein  perc.lactose   mass  neocortex.perc
# ...

# %%
df['K'] = (df['kcal.per.g']-df['kcal.per.g'].mean())/df['kcal.per.g'].std()
df['N'] = (df['neocortex.perc']-df['neocortex.perc'].mean())/df['neocortex.perc'].std()
df['M'] = (df['mass']-df['mass'].mean())/df['mass'].std()

# %%
df.head()
# Out:
#            clade         species  kcal.per.g  perc.fat  perc.protein  \
# 0  Strepsirrhine  Eulemur fulvus        0.49     16.60         15.42
# 1  Strepsirrhine        E macaco        0.51     19.27         16.91
# 2  Strepsirrhine        E mongoz        0.46     14.11         16.85
# 3  Strepsirrhine   E rubriventer        0.48     14.91         13.18
# 4  Strepsirrhine     Lemur catta        0.60     27.28         19.50
#
#    perc.lactose  mass  neocortex.perc         K         N         M
# 0         67.98  1.95           55.16 -0.940041 -2.080196 -0.515812
# 1         63.82  2.09             NaN -0.816126       NaN -0.510160
# 2         69.04  2.51             NaN -1.125913       NaN -0.493204
# 3         71.91  1.62             NaN -1.001998       NaN -0.529134
# 4         53.22  2.19             NaN -0.258511       NaN -0.506123

# %% [markdown]
# ### Model description

# %% [markdown]
# $$ K_i \sim N(\mu_i, \sigma) $$
# $$ \mu_i = \alpha + \beta_N N_i  $$

# %%
df = df.dropna()

# %%
df.head()
# Out:
#               clade             species  kcal.per.g  perc.fat  perc.protein  \
# 0     Strepsirrhine      Eulemur fulvus        0.49     16.60         15.42
# 5  New World Monkey  Alouatta seniculus        0.47     21.22         23.58
# 6  New World Monkey          A palliata        0.56     29.66         23.46
# 7  New World Monkey        Cebus apella        0.89     53.41         15.80
# 9  New World Monkey          S sciureus        0.92     50.58         22.33
#
#    perc.lactose  mass  neocortex.perc         K         N         M
# 0         67.98  1.95           55.16 -0.940041 -2.080196 -0.515812
# 5         55.20  5.25           64.54 -1.063955 -0.508641 -0.382588
# 6         46.88  5.37           64.54 -0.506340 -0.508641 -0.377744
# 7         30.79  2.51           67.64  1.538249  0.010742 -0.493204
# 9         27.09  0.68           68.85  1.724120  0.213470 -0.567082

# %% [markdown]
# $$ \alpha \sim N(0,1) $$
# $$ \beta_N \sim N(0,1) $$
# $$ \sigma \sim exp(0,1) $$

# %% [markdown]
# ## Testing priors

# %%
with pm.Model() as model_milk_1:
    alpha = pm.Normal('alpha', 0, 1)
    beta = pm.Normal('beta_n', 0, 1)
    sigma = pm.Exponential('sigma', 1)
    mu = pm.Deterministic('mu', alpha+beta*df['N'])
    K = pm.Normal('kcals', mu,sigma, observed = df['K'])
    trace_milk_1 = pm.sample(1000, tune= 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta_n, alpha]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:04<00:00, 1730.21draws/s]

# %%
pm.traceplot(trace_milk_1, varnames = ['alpha', 'beta_n', 'sigma']);

# %%
x_points = np.linspace(-2,2,50)
plt.plot(x_points, trace_milk_1['alpha'][:50]+trace_milk_1['beta_n'][:50]*x_points[:,None]);

# %%
with pm.Model() as model_milk_n:
    alpha = pm.Normal('alpha', 0, 0.2)
    beta = pm.Normal('beta_n', 0, 0.5)
    sigma = pm.Exponential('sigma', 1)
    mu = pm.Deterministic('mu', alpha+beta*df['N'])
    K = pm.Normal('kcals', mu,sigma, observed = df['K'])
    trace_milk_n = pm.sample(1000, tune= 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta_n, alpha]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:06<00:00, 1226.32draws/s]

# %%
x_points = np.linspace(-2,2,100)
plt.plot(x_points, trace_milk_n['alpha'] + trace_milk_1['beta_n'] * x_points[:,None]);

# %% [markdown]
# ### We will choose tighter priors, since  according to the data it is reasonable:
# with standardized variables, when the predictor variable is 0, the outcome should also be 0
#
# Also slope should be less steep, since the relationship can't be impossibly strong

# %%
pm.summary(trace_milk_n, varnames = ['alpha', 'beta_n', 'sigma'])
# Out:
#             mean        sd  mc_error   hpd_2.5  hpd_97.5        n_eff  \
# alpha   0.037144  0.158572  0.002209 -0.295654  0.331822  5495.326973
# beta_n  0.120258  0.240600  0.003258 -0.375791  0.564943  4571.031770
# sigma   1.108737  0.204205  0.003162  0.736221  1.508105  4298.010290
#
#             Rhat
# alpha   0.999532
# beta_n  0.999829
# sigma   1.000242

# %% [markdown]
# ### Neocortex as predictor

# %%
x_points = np.linspace(-2,2,100)
mu_pred = trace_milk_n['alpha'] + trace_milk_n['beta_n'] * x_points[:,None]
plt.plot(x_points, trace_milk_n['alpha'].mean() + trace_milk_n['beta_n'].mean() * x_points)
plt.scatter(df['N'], df['K'])
az.plot_hpd(x_points, mu_pred.T)

# %%
df['log_mass'] = np.log(df['mass'])
# Out:
# C:\Users\Mikko\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['M'] = (df['log_mass'] - df['log_mass'].mean())/df['log_mass'].std()
# Out:
# C:\Users\Mikko\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
with pm.Model() as model_milk_m:
    alpha = pm.Normal('alpha', 0, 0.2)
    beta = pm.Normal('beta_m', 0, 0.5)
    sigma = pm.Exponential('sigma', 1)
    mu = pm.Deterministic('mu', alpha+beta*df['M'])
    K = pm.Normal('kcals', mu,sigma, observed = df['K'])
    trace_milk_m = pm.sample(1000, tune= 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta_m, alpha]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:06<00:00, 1264.41draws/s]

# %% [markdown]
# ### log(mass) as predictor

# %%
x_points = np.linspace(-2,2,100)
mu_pred = trace_milk_m['alpha'] + trace_milk_m['beta_m'] * x_points[:,None]
plt.plot(x_points, trace_milk_m['alpha'].mean() + trace_milk_m['beta_m'].mean() * x_points)
plt.scatter(df['N'], df['K'])
az.plot_hpd(x_points, mu_pred.T)

# %% [markdown]
# ### neocortex and mass as predictors

# %% [markdown]
# $$ K_i \sim N(\mu_i, \sigma) $$
# $$ \mu_i = \alpha + \beta_N N_i + \beta_M M_i $$
# $$ \alpha \sim N(0,0.2) $$
# $$ \beta_n \sim N(0,0.5) $$
# $$ \beta_m \sim N(0, 0.5) $$
# $$ \sigma \sim Exp(1) $$

# %%
with pm.Model() as model_milk_mn:
    beta_n = pm.Normal('beta_n', 0, 0.5)
    beta_m = pm.Normal('beta_m', 0, 0.5)
    alpha = pm.Normal('alpha', 0,0.2)
    sigma = pm.Exponential('sigma', 1)
    mu =  pm.Deterministic('mu', alpha + beta_n * df['N'] + beta_m * df['M'])
    K = pm.Normal('K', mu, sigma, observed = df['K'])
    trace_milk_mn = pm.sample(1000,tune = 1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, alpha, beta_m, beta_n]
# Sampling 4 chains: 100%|██████████████████████████████████████████████████████| 8000/8000 [00:05<00:00, 1413.29draws/s]

# %%
az.summary(trace_milk_mn)
# Out:
#          mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# beta_n  0.568  0.271   0.061    1.061      0.006    0.004    2290.0  2290.0
# beta_m -0.674  0.275  -1.186   -0.145      0.006    0.004    2377.0  2377.0
# alpha   0.046  0.145  -0.224    0.322      0.003    0.002    3202.0  2387.0
# sigma   0.871  0.173   0.588    1.203      0.004    0.003    2345.0  2305.0
# mu[0]  -0.846  0.511  -1.713    0.204      0.010    0.007    2662.0  2662.0
# mu[1]  -0.298  0.211  -0.676    0.110      0.004    0.003    2681.0  2681.0
# mu[2]  -0.306  0.213  -0.685    0.107      0.004    0.003    2667.0  2667.0
# mu[3]   0.254  0.167  -0.089    0.545      0.003    0.002    2707.0  2651.0
# mu[4]   0.824  0.342   0.185    1.458      0.007    0.005    2196.0  2196.0
# mu[5]   0.477  0.407  -0.276    1.233      0.006    0.005    4603.0  3677.0
# mu[6]   0.272  0.280  -0.293    0.756      0.004    0.003    4384.0  3265.0
# ...

# %%
import ptitprince as pt

# %%
df_n = pd.DataFrame([['beta_n', 'n'], ['beta_n', 'mn']], columns = ['slope', 'simulation'])
df_m = pd.DataFrame([['beta_m', 'm'], ['beta_m', 'mn']], columns = ['slope', 'simulation'])

# %%
index_n = pd.MultiIndex.from_frame(df_n)
index_m = pd.MultiIndex.from_frame(df_m)

# %%
df_n = pd.DataFrame([trace_milk_n['beta_n'],trace_milk_mn['beta_n']], index = index_n)
df_m = pd.DataFrame([trace_milk_m['beta_m'],trace_milk_mn['beta_m']], index = index_m)

# %%
df_n = pd.DataFrame(df_n.stack())
df_m = pd.DataFrame(df_m.stack())

# %%
df_n = df_n.reset_index()
df_m = df_m.reset_index()

# %%
df_n.columns = ['slope', 'simulation','index','standardized value']
df_m.columns = ['slope', 'simulation','index','standardized value']

# %%
ax =pt.RainCloud( x = "simulation", y = 'standardized value', data = df_n, orient = "h", figsize = (7,5))
plt.title("beta_n",  fontsize=26)
# Out:
# Text(0.5, 1.0, 'beta_n')

# %%
ax = pt.RainCloud( x= 'simulation', y = 'standardized value', data = df_m, orient = 'h', figsize = (7,5))
plt.title("beta_m", fontsize = 26)
# Out:
# Text(0.5, 1.0, 'beta_m')

# %% [markdown]
# ### M influences N

# %%
G = nx.DiGraph()
G.add_node('M')
G.add_node('N')
G.add_node('K')

G.add_edge('M','K')
G.add_edge('N','K')
G.add_edge('M','N')

pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels = True)

# %% [markdown]
# ### N influences M

# %%
G = nx.DiGraph()
G.add_node('M')
G.add_node('N')
G.add_node('K')

G.add_edge('M','K')
G.add_edge('N','K')
G.add_edge('N','M')

pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels = True)

# %% [markdown]
# ### U influences N and M

# %%
G = nx.DiGraph()

G.add_node('M')
G.add_node('U')
G.add_node('N')
G.add_node('K')


G.add_edge('M','K')
G.add_edge('N','K')
G.add_edge('U','M')
G.add_edge('U','N')

pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels = True)

# %% [markdown]
# ### Counterfactual plots

# %%
x_points = np.linspace(-2, 2, 100)
plt.plot(x_points, trace_milk_mn['alpha'].mean() + trace_milk_mn['beta_m'].mean()* x_points)
mu_pred = trace_milk_mn['alpha'] + np.outer(trace_milk_mn['beta_m'], x_points).T
randoms = stats.norm.rvs(mu_pred, trace_milk_mn['sigma'])
az.plot_hpd(x_points, randoms.T)
az.plot_hpd(x_points, mu_pred.T)
plt.ylim(bottom = -1, top = 2)
# Out:
# (-1, 2)

# %%
x_points = np.linspace(-2, 2, 100)
plt.plot(x_points, trace_milk_mn['alpha'].mean() + trace_milk_mn['beta_n'].mean()* x_points)
mu_pred = trace_milk_mn['alpha'] + np.outer(trace_milk_mn['beta_n'], x_points).T
randoms = stats.norm.rvs(mu_pred, trace_milk_mn['sigma'])
az.plot_hpd(x_points, randoms.T)
az.plot_hpd(x_points, mu_pred.T)
plt.ylim(bottom = -1, top = 2)
# Out:
# (-1, 2)

# %%
df = pd.read_csv('../resources/Rethinking/Data/Howell1.csv', sep = ';')

# %% [markdown]
# ###  Easy 5_1

# %%
All of them are multiple linear regressions

# %% [markdown]
# ### Easy 5_2

# %% [markdown]
# $$ D_i \sim N(\mu_i, \sigma)$$
# $$ \mu_i = \alpha + \beta_P P_i + \beta_A A_i $$

# %% [markdown]
# ### Easy 5_3

# %% [markdown]
# $$ \mu_i = \alpha + \beta_s S_i + \beta_f F_i$$

# %%
N = 100
x_real = stats.norm.rvs(loc=0,scale = 1, size = N)
x_spur = stats.norm.rvs(loc = 0, scale = 1, size = N)
y = stats.norm.rvs(loc = x_real + x_spur, scale = 1, size = N)

# %%
d = pd.DataFrame()
d['x_real'] = x_real
d['x_spur'] = x_spur
d['y'] = y

# %%
d.head()
# Out:
#      x_real    x_spur         y
# 0  1.557331  0.723271  2.126784
# 1 -0.503106  0.881712  0.023311
# 2 -0.708460 -2.178117 -2.385463
# 3  0.743262  0.273627 -0.788522
# 4  0.145404 -0.769865 -1.005294

# %%
import seaborn as sns

# %%
sns.pairplot(d)

# %%
az.plot_kde(x_real)

# %%
df = pd.read_csv('../resources/Rethinking/Data/Howell1.csv', sep=';')

# %%
df.head()
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041915  41.0     1
# 4  145.415  41.276872  51.0     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 4 columns):
# height    544 non-null float64
# weight    544 non-null float64
# age       544 non-null float64
# male      544 non-null int64
# dtypes: float64(3), int64(1)
# memory usage: 17.1 KB

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [height, weight, age, male]
# Index: []
